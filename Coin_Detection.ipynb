# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('pic/coin.jpg', 1)

# %%
img_cp = img.copy()

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img, cmap="gray")

# %%
plt.imshow(img)

# %%
ret, thresh = cv2.threshold(img, 0, 255, cv2.THRESH_OTSU)

# %%
plt.imshow(thresh)

# %%
se = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))

# %%
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, se)

# %%
plt.imshow(closing, cmap="gray")

# %%
ret,thresh = cv2.threshold(closing, 127, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

cv2.drawContours(img, contours, -1, (255,0,0), 3)
plt.imshow(img)
plt.title("Line test")
# Out:
# Text(0.5, 1.0, 'Line test')

# %%
all_circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,65,
                            param1=50,param2=30,minRadius=0,maxRadius=0)

# %%
all_round = np.uint16(np.around(all_circles))

# %%
"I have : " + str(all_round.shape[1]) + " coins"
# Out:
# 'I have : 21 coins'
