# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/poomwarawat/LearningAI'

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('pic/input.PNG', 0)

# %% [raw]
# img.shape

# %%
kernel = np.ones((5, 5), np.uint8)

# %%
img_erosion = cv2.erode(img, kernel, iterations=1)
img_dilation = cv2.dilate(img, kernel, iterations=1)

# %%
plt.imshow(img_erosion, cmap="gray")

# %%
plt.imshow(img_dilation, cmap="gray")

# %%
# %matplotlib inline

# %%
gray_image = cv2.imread(('pic/coin.jpg'), 1)

# %%
plt.imshow(gray_image, cmap="gray")

# %%
ret, thresh = cv2.threshold(gray_image, 0, 255, cv2.THRESH_OTSU)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-69-0a8f6ca3d07a> in <module>
# ----> 1 ret, thresh = cv2.threshold(gray_image, 0, 255, cv2.THRESH_OTSU)
#
# error: OpenCV(4.1.2) /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/thresh.cpp:1527: error: (-215:Assertion failed) src.type() == CV_8UC1 in function 'threshold'

# %%
plt.imshow(thresh, cmap="gray")
plt.title("Thresh Image")
plt.axis("off")
# Out:
# (-0.5, 399.5, 288.5, -0.5)

# %%
img1 = thresh.copy()

# %%
se = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))

# %%
erosion = cv2.erode(img1, se, iterations=1)

# %%
plt.imshow(erosion, cmap="gray")
plt.title("Erosion Image")
plt.axis("off")
# Out:
# (-0.5, 399.5, 288.5, -0.5)

# %%
dilation = cv2.dilate(img1, se, iterations=1)

# %%
plt.imshow(dilation, cmap="gray")
plt.title("Dilation Image")
plt.axis("off")
# Out:
# (-0.5, 399.5, 288.5, -0.5)

# %%
opening = cv2.morphologyEx(img1, cv2.MORPH_CLOSE, se)

# %%
plt.imshow(opening, cmap="gray")
plt.title("Open Image")
plt.axis("off")
# Out:
# (-0.5, 399.5, 288.5, -0.5)

# %%
closing = cv2.morphologyEx(img1, cv2.MORPH_CLOSE, se)

# %%
plt.imshow(closing, cmap="gray")
plt.title("closing Image")
plt.axis("off")
# Out:
# (-0.5, 399.5, 288.5, -0.5)

# %%
im = cv2.imread('pic/coin.jpg', 1)

# %%
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

# %%
ret, thresh = cv2.threshold(gray, 127, 255, 0)

# %%
im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-79632fe675b3> in <module>
# ----> 1 im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#
# ValueError: not enough values to unpack (expected 3, got 2)
